# %%
# LIBRERÍAS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, kstest
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames
from itertools import combinations  # para las medidas de correlación
import warnings
warnings.filterwarnings("ignore")

# %%
from src import functions

# %% [markdown]
# ### Pair ETL I

# %% [markdown]
# Ejercicios ETL Parte I
#
# En este caso trabajas en una empresa de venta al por menor de productos italianos y debes realizar la limpieza, transformación e integración de datos de ventas, productos y clientes para su análisis.
#
# Los pasos que deberás seguir en este ejercicio son:

# %% [markdown]
# **Lectura de la Información:**

# %% [markdown]
# - Leer los archivos CSV (ventas.csv, productos.csv, clientes.csv).

# %%
ventas_df = pd.read_csv('ventas.csv')
ventas_df.head()
# Out:
#    ID_Cliente ID_Producto Fecha_Venta  Cantidad  Total
# 0         723          A1  2023-11-22         2  17.98
# 1         498          C3  2023-11-21         1   5.49
# 2         121          D4  2023-11-20         3  32.97
# 3         885         L12  2023-11-19         1   6.49
# 4         347         Q17  2023-11-18         2   7.98

# %%
clientes_df = pd.read_csv('clientes.csv')
clientes_df
# Out:
#        id  first_name last_name                         email  gender  \
# 0       1       Cheri  Dunsmore      cdunsmore0@instagram.com  Female
# 1       2        Hunt  Bartomeu         hbartomeu1@nsw.gov.au    Male
# 2       3  Michaeline   Paynton            mpaynton2@narod.ru  Female
# 3       4      Filmer    Eirwin            feirwin3@intel.com     NaN
# 4       5      Tanhya   Lubbock  tlubbock4@huffingtonpost.com  Female
# ..    ...         ...       ...                           ...     ...
# 995   996         Ray    Tarpey      rtarpeyrn@bravesites.com  Female
# 996   997        Flem  Roderham       froderhamro@dropbox.com    Male
# 997   998   Winifield    Blakes         wblakesrp@jiathis.com    Male
# 998   999      Lanita  Espinosa        lespinosarq@discuz.net  Female
# 999  1000     Grissel   Siberry     gsiberryrr@wikispaces.com  Female
#
#                             City Country                   Address
# 0              Palma De Mallorca   Spain  076 Rockefeller Crossing
# 1                           Lugo   Spain        0046 Utah Junction
# 2                            NaN   Spain          0 Corry Crossing
# 3                           Leon   Spain       5 American Ash Road
# 4    Hospitalet De Llobregat, L'   Spain         9289 Merry Circle
# ..                           ...     ...                       ...
# 995                       Zamora   Spain     36384 Sommers Terrace
# 996                   Pontevedra   Spain    93177 Eastwood Parkway
# 997                         Vigo   Spain       03044 Grayhawk Road
# 998                 Dos Hermanas   Spain        2 Schmedeman Drive
# 999                         Leon   Spain     42274 Waywood Terrace
#
# [1000 rows x 8 columns]

# %% [markdown]
# - Explorar los conjuntos de datos para comprender su estructura, columnas, tipos de datos, etc.

# %%
exploracion_datos(ventas_df)
# Out:
# _____________ INFORMACIÓN GENERAL DEL DATAFRAME ____________
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID_Cliente   100 non-null    int64
#  1   ID_Producto  100 non-null    object
#  2   Fecha_Venta  100 non-null    object
#  3   Cantidad     100 non-null    int64
#  4   Total        100 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ KB
# None
# ___________________ FORMA DEL DATAFRAME ____________________
#
# El número de filas que tenemos es de 100.
# El número de columnas es de 5
#
# _______________ NULOS, ÚNICOS Y DUPLICADOS _________________
#
# La cantidad de valores NULOS por columna es de:
#
# ID_Cliente     0
# ID_Producto    0
# Fecha_Venta    0
# Cantidad       0
# Total          0
# dtype: int64
# ____________________________________________________________
#
# La cantidad de valores ÚNICOS por columna es de:
#
# La columna ID_Cliente: 30
# La columna ID_Producto: 100
# La columna Fecha_Venta: 80
# La columna Cantidad: 3
# La columna Total: 28
# ____________________________________________________________
#
# La cantidad de valores DUPLICADOS por columna es de:
#
# La columna ID_Cliente: 70
# La columna ID_Producto: 0
# La columna Fecha_Venta: 20
# La columna Cantidad: 97
# La columna Total: 72
# ____________________ RESUMEN ESTADÍSTICO ____________________
# ____________________ Variables Numéricas __________________
#
#             count      mean         std    min     25%     50%    75%     max
# ID_Cliente  100.0  572.0500  290.403877  29.00  234.00  543.00  876.0  987.00
# Cantidad    100.0    1.6500    0.729951   1.00    1.00    1.50    2.0    3.00
# Total       100.0   11.2005    7.031316   4.25    5.93    8.75   12.5   32.97
# ___________________ Variables Categóricas _________________
#
#             count unique         top freq
# ID_Producto   100    100          A1    1
# Fecha_Venta   100     80  2023-10-24    2

# %%
exploracion_datos(clientes_df)
# Out:
# _____________ INFORMACIÓN GENERAL DEL DATAFRAME ____________
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       973 non-null    object
#  4   gender      923 non-null    object
#  5   City        876 non-null    object
#  6   Country     846 non-null    object
#  7   Address     959 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 62.6+ KB
# None
# ___________________ FORMA DEL DATAFRAME ____________________
#
# El número de filas que tenemos es de 1000.
# El número de columnas es de 8
#
# _______________ NULOS, ÚNICOS Y DUPLICADOS _________________
#
# La cantidad de valores NULOS por columna es de:
#
# id              0
# first_name      0
# last_name       0
# email          27
# gender         77
# City          124
# Country       154
# Address        41
# dtype: int64
# ____________________________________________________________
#
# La cantidad de valores ÚNICOS por columna es de:
#
# La columna id: 1000
# La columna first_name: 940
# La columna last_name: 986
# La columna email: 974
# La columna gender: 9
# La columna City: 56
# La columna Country: 2
# La columna Address: 959
# ____________________________________________________________
#
# La cantidad de valores DUPLICADOS por columna es de:
#
# La columna id: 0
# La columna first_name: 60
# La columna last_name: 14
# La columna email: 26
# La columna gender: 991
# La columna City: 944
# La columna Country: 998
# La columna Address: 41
# ____________________ RESUMEN ESTADÍSTICO ____________________
# ____________________ Variables Numéricas __________________
#
#      count   mean         std  min     25%    50%     75%     max
# id  1000.0  500.5  288.819436  1.0  250.75  500.5  750.25  1000.0
# ___________________ Variables Categóricas _________________
#
#            count unique                       top freq
# first_name  1000    940                   Germain    3
# last_name   1000    986                 Bartolini    2
# email        973    973  cdunsmore0@instagram.com    1
# gender       923      8                      Male  424
# City         876     55                    Madrid   51
# Country      846      1                     Spain  846
# Address      959    958            7 Toban Center    2

# %% [markdown]
# **Transformación de Datos:**

# %% [markdown]
# - Limpiar los datos: manejar valores nulos, eliminar duplicados si los hay, corregir errores tipográficos, etc.

# %% [markdown]
# - Realizar la integración de datos: unir los conjuntos de datos apropiados para obtener una tabla única que contenga información de ventas junto con detalles de productos y clientes.

# %% [markdown]
# - Aplicar transformaciones relevantes según sea necesario: por ejemplo, convertir tipos de datos, renombrar columnas, crear nuevas características derivadas, etc.
# NOTA Este ejercicio debe realizarse en un archivo .py

# %%
ver_duplicados(clientes_df, 'email')
# Out:
#       id first_name     last_name email       gender  \
# 7      8     Aubree         Jirsa   NaN       Female
# 16    17      Yance    Martinetto   NaN         Male
# 42    43     Salmon  Ricciardello   NaN         Male
# 81    82        Uta      Crasford   NaN       Female
# 167  168      Storm       Musterd   NaN       Female
# 171  172    Madonna     McClymond   NaN       Female
# 211  212     Darsey       Scargle   NaN       Female
# 213  214     Hallsy        Deeney   NaN         Male
# 215  216       Alva      Gauchier   NaN         Male
# 231  232   Ethelred       Aireton   NaN         Male
# 407  408    Brittne         Weich   NaN  Genderfluid
# 417  418      Urban      Mapstone   NaN         Male
# 439  440     Kalila     Goldspink   NaN       Female
# 445  446      Gerri   Widdowfield   NaN         Male
# 454  455      Mateo    Davidovits   NaN         Male
# 478  479       Lana    Kirkbright   NaN       Female
# 538  539    Margalo      Steketee   NaN       Female
# 577  578    Malinda      Baldazzi   NaN      Agender
# 592  593     Noreen         Crann   NaN       Female
# 600  601    Cecilia          Lush   NaN       Female
# 601  602     Renaud     Aberkirdo   NaN         Male
# 665  666      Micki  Van Der Hoog   NaN       Female
# 732  733     Lazare      Anderton   NaN          NaN
# 778  779    Rozanne      Rolinson   NaN       Female
# 845  846    Nicolle       Erridge   NaN       Female
# 878  879  Gabrielle      Iwanczyk   NaN       Female
# 988  989    Jermain     Klassmann   NaN          NaN
#
#                             City Country                   Address
# 7                      Santander     NaN         8294 Schurz Court
# 16                Pamplona/Iruña   Spain             4 Anthes Pass
# 42        Donostia-San Sebastian   Spain        5237 Montana Drive
# 81                          Lugo   Spain                       NaN
# 167                      Badajoz   Spain                       NaN
# 171  Palmas De Gran Canaria, Las   Spain   70142 Prairieview Point
# 211                    Coruña, A     NaN       04988 Roxbury Court
# 213                    Barcelona   Spain  8684 Crescent Oaks Trail
# 215                      Badajoz     NaN         7 Cherokee Center
# 231                          NaN   Spain         6166 Starling Way
# 407                   Pontevedra   Spain            763 Mayer Lane
# 417                          NaN   Spain         1 Sullivan Circle
# 439                      Sevilla     NaN         973 Loomis Avenue
# 445                       Lleida     NaN        61207 Granby Drive
# 454       Santiago De Compostela   Spain        17906 Miller Court
# 478                   Pontevedra   Spain              3 Lawn Court
# 538                       Zamora   Spain          7 Warbler Street
# 577                   Torrevieja   Spain      4079 Westend Parkway
# 592                         Leon   Spain       875 Lake View Point
# 600                       Malaga   Spain      03819 Mallard Avenue
# 601                          NaN   Spain           112 Gerald Lane
# 665                    Barcelona   Spain              4 Hayes Hill
# 732                       Girona   Spain           16 Grover Point
# 778                        Cadiz   Spain      8239 Porter Junction
# 845                   Pontevedra   Spain         7336 Upham Circle
# 878                     Valencia   Spain            01 Onsgard Way
# 988            Palma De Mallorca     NaN    8083 Burning Wood Pass

# %%
ver_duplicados(clientes_df, 'Address')
# Out:
#       id first_name    last_name                           email      gender  \
# 9     10       Igor      Dwelley            idwelley9@flickr.com        Male
# 34    35       Egon      Lafflin                elaffliny@a8.net        Male
# 72    73    Reinald       Platts             rplatts20@phpbb.com         NaN
# 73    74       Tate     Capehorn         tcapehorn21@comsenz.com        Male
# 81    82        Uta     Crasford                             NaN      Female
# 114  115     Carole     Biasetti             cbiasetti36@soup.io      Female
# 147  148    Carling        Pharo              cpharo43@youku.com        Male
# 156  157     Nancie    Radcliffe        nradcliffe4c@mozilla.org      Female
# 167  168      Storm      Musterd                             NaN      Female
# 175  176    Darrick       Lennox       dlennox4v@ycombinator.com        Male
# 189  190     Nancey      Fellnee             nfellnee59@cnet.com      Female
# 197  198  Corabelle        Goble              cgoble5h@fotki.com      Female
# 210  211      Bette       Fozard   bfozard5u@cargocollective.com      Female
# 242  243     Laurie      Harlowe        lharlowe6q@csmonitor.com         NaN
# 250  251      Brand      Haydney             bhaydney6y@usda.gov        Male
# 253  254   Sterling     Armstead          sarmstead71@unesco.org        Male
# 267  268    Yardley         Back           yback7f@discovery.com        Male
# 301  302     Berrie       Rubury   brubury8d@constantcontact.com  Polygender
# 374  375     Elisha      Pinwill           epinwillae@devhub.com      Female
# 380  381     Shelli      Cellier            scellierak@unblog.fr      Female
# 503  504    Desirae    Faircliff         dfaircliffdz@zimbio.com      Female
# 548  549    Vasilis     Vaughton              vvaughtonf8@goo.gl        Male
# 611  612   Germaine       Dragoe               gdragoegz@msn.com        Male
# 717  718      Corby  Le Marquand       clemarquandjx@youtube.com        Male
# 721  722    Ignacio      McComas         imccomask1@blogspot.com        Male
# 724  725       Nara    Fumagalli         nfumagallik4@scribd.com      Female
# 733  734       Abbe      Caunter  acaunterkd@cargocollective.com         NaN
# 738  739      Amory      Laherty              alahertyki@wix.com        Male
# 776  777       Noel  Mugglestone      nmugglestonelk@arizona.edu        Male
# 784  785       Olva      Cahalan            ocahalanls@ifeng.com      Female
# 787  788      Lissa        Regan           lreganlv@multiply.com      Female
# 805  806  Josephina          Doy         jdoymd@wunderground.com      Female
# 814  815    Ruperta       Meaker            rmeakermm@paypal.com      Female
# 847  848    Dorette         Muck     dmucknj@theglobeandmail.com      Female
# 848  849    Annabal    Blockwell      ablockwellnk@google.com.au    Bigender
# 855  856  Alejandro        Chese             achesenr@zimbio.com        Male
# 858  859      Luisa     Adelberg   ladelbergnu@elegantthemes.com      Female
# 910  911     Lorrin   O'Donoghue        lodonoghuepa@jiathis.com      Female
# 913  914     Garald      Billson          gbillsonpd@latimes.com        Male
# 942  943    Maritsa        Doale              mdoaleq6@google.nl         NaN
# 946  947     Jamill       Lewson         jlewsonqa@cafepress.com        Male
# 973  974       Luke       Insley               linsleyr1@ftc.gov        Male
# 977  978   Cindelyn      Elbourn            celbournr5@hc360.com      Female
#
#                             City Country         Address
# 9                           Lugo   Spain             NaN
# 34                       Sevilla   Spain             NaN
# 72                        Malaga   Spain             NaN
# 73                     Barcelona   Spain             NaN
# 81                          Lugo   Spain             NaN
# 114                          NaN   Spain             NaN
# 147       Donostia-San Sebastian   Spain             NaN
# 156                          NaN   Spain             NaN
# 167                      Badajoz   Spain             NaN
# 175                          NaN     NaN             NaN
# 189                          NaN   Spain             NaN
# 197                    Santander   Spain             NaN
# 210                     Valencia     NaN             NaN
# 242                        Ceuta   Spain             NaN
# 250                       Lleida   Spain             NaN
# 253                       Aviles   Spain             NaN
# 267                    Barcelona   Spain  7 Toban Center
# 301                      Leganes   Spain             NaN
# 374  Palmas De Gran Canaria, Las   Spain             NaN
# 380               Pamplona/Iruña   Spain             NaN
# 503                   Valladolid     NaN             NaN
# 548       Donostia-San Sebastian   Spain             NaN
# 611                          NaN     NaN             NaN
# 717                    Cartagena   Spain             NaN
# 721                      Almeria   Spain             NaN
# 724              Vitoria-Gasteiz   Spain             NaN
# 733                         Jaen     NaN             NaN
# 738                          NaN   Spain             NaN
# 776                       Zamora   Spain             NaN
# 784                   Pontevedra   Spain             NaN
# 787                        Cadiz   Spain             NaN
# 805                      Leganes   Spain             NaN
# 814                     Albacete   Spain             NaN
# 847                      Ourense   Spain             NaN
# 848                      Granada   Spain             NaN
# 855                     Palencia   Spain             NaN
# 858                       Murcia   Spain             NaN
# 910            Palma De Mallorca   Spain             NaN
# 913                          NaN     NaN             NaN
# 942                          NaN   Spain  7 Toban Center
# 946  Hospitalet De Llobregat, L'   Spain             NaN
# 973               Pamplona/Iruña   Spain             NaN
# 977                        Ceuta   Spain             NaN

# %%
pasar_minuscula(ventas_df)
# Out:
# {'ID_Cliente': 'id_cliente',
#  'ID_Producto': 'id_producto',
#  'Fecha_Venta': 'fecha_venta',
#  'Cantidad': 'cantidad',
#  'Total': 'total'}

# %%
pasar_minuscula(clientes_df)
# Out:
# {'id': 'id',
#  'first_name': 'first_name',
#  'last_name': 'last_name',
#  'email': 'email',
#  'gender': 'gender',
#  'City': 'city',
#  'Country': 'country',
#  'Address': 'address'}

# %%
clientes_df['Country'].unique()
# Out:
# array(['Spain', nan], dtype=object)

# %%
clientes_df['City'].mode()
# Out:
# 0    Madrid
# Name: City, dtype: object

# %%
conteo_columnas_cat(clientes_df)
# Out:
# "Las columnas categóricas que tienen nulos son : Index(['email', 'gender', 'City', 'Address'], dtype='object')"

# %%
reemplazar_nulos_por_moda(clientes_df, 'Country')
# Out:
# 'Hay 0 nulos'

# %%
reemplazar_unknown(columnas_desconocido, clientes_df)
# Out:
# Después del reemplazo usando 'fillna' quedan los siguientes nulos
# City       0
# email      0
# Address    0
# gender     0
# dtype: int64
