# %% [markdown]
# ### Ejercicios apply
#
# Las columnas land_area, armed_forces_size, co2-emissions, gdp, population, urban_population, latitude, longitude, density, cpi son de tipo object pero en realidad deberían ser numéricas. Crea una función que nos permita cambiar el tipo de dato de estas columnas al que le corresponde.

# %%
import pandas as pd
import numpy as np
import re

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

df_inner = pd.read_csv('df_world_unido.csv')
df_inner.head(5)
# Out:
#        country density abbreviation  agriculturalland   landarea  \
# 0  Afghanistan      60           AF              58.1    652,230
# 1      Albania     105           AL              43.1     28,748
# 2      Algeria      18           DZ              17.4  2,381,741
# 3      Andorra     164           AD              40.0        468
# 4       Angola      26           AO              47.5  1,246,700
#
#   armedforcessize  birthrate  callingcode  capitalmajorcity co2emissions  \
# 0         323,000      32.49         93.0             Kabul        8,672
# 1           9,000      11.78        355.0            Tirana        4,536
# 2         317,000      24.28        213.0           Algiers      150,006
# 3             NaN       7.20        376.0  Andorra la Vella          469
# 4         117,000      40.73        244.0            Luanda       34,693
#
#       cpi  cpichange currencycode  fertilityrate  forestedarea  gasolineprice  \
# 0   149.9        2.3          AFN           4.47           2.1           0.70
# 1  119.05        1.4          ALL           1.62          28.1           1.36
# 2  151.36        2.0          DZD           3.02           0.8           0.28
# 3     NaN        NaN          EUR           1.27          34.0           1.51
# 4  261.73       17.1          AOA           5.52          46.3           0.97
#
#                 gdp  grossprimaryeducationenrollment  \
# 0   19,101,353,833                             104.0
# 1   15,278,077,447                             107.0
# 2  169,988,236,398                             109.9
# 3    3,154,057,987                             106.4
# 4   94,635,415,870                             113.5
#
#    grosstertiaryeducationenrollment  infantmortality       largestcity  \
# 0                               9.7             47.9             Kabul
# 1                              55.0              7.8            Tirana
# 2                              51.4             20.1           Algiers
# 3                               NaN              2.7  Andorra la Vella
# 4                               9.3             51.6            Luanda
#
#    lifeexpectancy  maternalmortalityratio  minimumwage officiallanguage  \
# 0            64.5                   638.0         0.43           Pashto
# 1            78.5                    15.0         1.12         Albanian
# 2            76.7                   112.0         0.95           Arabic
# 3             NaN                     NaN         6.63          Catalan
# 4            60.8                   241.0         0.71       Portuguese
#
#    outofpockethealthexpenditure  physiciansperthousand  population  \
# 0                          78.4                   0.28  38,041,754
# 1                          56.9                   1.20   2,854,191
# 2                          28.1                   1.72  43,053,054
# 3                          36.4                   3.33      77,142
# 4                          33.4                   0.21  31,825,295
#
#    populationlaborforceparticipation  taxrevenue  totaltaxrate  \
# 0                               48.9         9.3          71.4
# 1                               55.7        18.6          36.6
# 2                               41.2        37.2          66.1
# 3                                NaN         NaN           NaN
# 4                               77.5         9.2          49.1
#
#    unemploymentrate urbanpopulation       longitude       latitude
# 0             11.12       9,797,273    ('33.93911 '   '67.709953')
# 1             12.33       1,747,593   ('41.153332 '   '20.168331')
# 2             11.70      31,510,100   ('28.033886 '    '1.659626')
# 3               NaN          67,873   ('42.506285 '    '1.521801')
# 4              6.89      21,061,025  ('-11.202692 '   '17.873887')

# %%
#funcion para reemplazar comas por puntos
def comas_puntos(cadena):
    #eliminar espacios en blanco al inicio y al final
    cadena = cadena.str.strip()
    #reemplazar los parentesis y las comas por nada para eliminar separadores de miles
    cadena = cadena.str.replace(r"[',\(\)]", '', regex = True)
    #si existe un  punto decimal, conservarlo
    return cadena


#aplicar la funcion a las columnas

lista_columnas = ['landarea', 'armedforcessize', 'co2emissions', 'gdp', 'population', 'urbanpopulation', 'latitude', 'longitude', 'density', 'cpi']

for col in lista_columnas:
    df_inner[col] = comas_puntos(df_inner[col])

# %%
#convertir las columnas a tipo numerico, el parámetro errors='coerce' en pd.to_numeric() para manejar cualquier valor que no pueda ser convertido a número.

df_inner[lista_columnas] = df_inner[lista_columnas].apply(pd.to_numeric, errors ='coerce')

# %%
df_inner.head()
# Out:
#        country  density abbreviation  agriculturalland   landarea  \
# 0  Afghanistan       60           AF              58.1   652230.0
# 1      Albania      105           AL              43.1    28748.0
# 2      Algeria       18           DZ              17.4  2381741.0
# 3      Andorra      164           AD              40.0      468.0
# 4       Angola       26           AO              47.5  1246700.0
#
#    armedforcessize  birthrate  callingcode  capitalmajorcity  co2emissions  \
# 0         323000.0      32.49         93.0             Kabul        8672.0
# 1           9000.0      11.78        355.0            Tirana        4536.0
# 2         317000.0      24.28        213.0           Algiers      150006.0
# 3              NaN       7.20        376.0  Andorra la Vella         469.0
# 4         117000.0      40.73        244.0            Luanda       34693.0
#
#       cpi  cpichange currencycode  fertilityrate  forestedarea  gasolineprice  \
# 0  149.90        2.3          AFN           4.47           2.1           0.70
# 1  119.05        1.4          ALL           1.62          28.1           1.36
# 2  151.36        2.0          DZD           3.02           0.8           0.28
# 3     NaN        NaN          EUR           1.27          34.0           1.51
# 4  261.73       17.1          AOA           5.52          46.3           0.97
#
#             gdp  grossprimaryeducationenrollment  \
# 0  1.910135e+10                            104.0
# 1  1.527808e+10                            107.0
# 2  1.699882e+11                            109.9
# 3  3.154058e+09                            106.4
# 4  9.463542e+10                            113.5
#
#    grosstertiaryeducationenrollment  infantmortality       largestcity  \
# 0                               9.7             47.9             Kabul
# 1                              55.0              7.8            Tirana
# 2                              51.4             20.1           Algiers
# 3                               NaN              2.7  Andorra la Vella
# 4                               9.3             51.6            Luanda
#
#    lifeexpectancy  maternalmortalityratio  minimumwage officiallanguage  \
# 0            64.5                   638.0         0.43           Pashto
# 1            78.5                    15.0         1.12         Albanian
# 2            76.7                   112.0         0.95           Arabic
# 3             NaN                     NaN         6.63          Catalan
# 4            60.8                   241.0         0.71       Portuguese
#
#    outofpockethealthexpenditure  physiciansperthousand  population  \
# 0                          78.4                   0.28  38041754.0
# 1                          56.9                   1.20   2854191.0
# 2                          28.1                   1.72  43053054.0
# 3                          36.4                   3.33     77142.0
# 4                          33.4                   0.21  31825295.0
#
#    populationlaborforceparticipation  taxrevenue  totaltaxrate  \
# 0                               48.9         9.3          71.4
# 1                               55.7        18.6          36.6
# 2                               41.2        37.2          66.1
# 3                                NaN         NaN           NaN
# 4                               77.5         9.2          49.1
#
#    unemploymentrate  urbanpopulation  longitude   latitude
# 0             11.12        9797273.0  33.939110  67.709953
# 1             12.33        1747593.0  41.153332  20.168331
# 2             11.70       31510100.0  28.033886   1.659626
# 3               NaN          67873.0  42.506285   1.521801
# 4              6.89       21061025.0 -11.202692  17.873887

# %%
# Luego comprobamos que las columnas se convirtieron realmente a float

df_inner[lista_columnas].dtypes
# Out:
# landarea           float64
# armedforcessize    float64
# co2emissions       float64
# gdp                float64
# population         float64
# urbanpopulation    float64
# latitude           float64
# longitude          float64
# density              int64
# cpi                float64
# dtype: object

# %% [markdown]
# Crea una función para añadir una nueva columna llamada 'Continent' al DataFrame para indicar a qué continente pertenece cada país.

# %%
df_inner.head(2)
# Out:
#        country  density abbreviation  agriculturalland  landarea  \
# 0  Afghanistan       60           AF              58.1  652230.0
# 1      Albania      105           AL              43.1   28748.0
#
#    armedforcessize  birthrate  callingcode capitalmajorcity  co2emissions  \
# 0         323000.0      32.49         93.0            Kabul        8672.0
# 1           9000.0      11.78        355.0           Tirana        4536.0
#
#       cpi  cpichange currencycode  fertilityrate  forestedarea  gasolineprice  \
# 0  149.90        2.3          AFN           4.47           2.1           0.70
# 1  119.05        1.4          ALL           1.62          28.1           1.36
#
#             gdp  grossprimaryeducationenrollment  \
# 0  1.910135e+10                            104.0
# 1  1.527808e+10                            107.0
#
#    grosstertiaryeducationenrollment  infantmortality largestcity  \
# 0                               9.7             47.9       Kabul
# 1                              55.0              7.8      Tirana
#
#    lifeexpectancy  maternalmortalityratio  minimumwage officiallanguage  \
# 0            64.5                   638.0         0.43           Pashto
# 1            78.5                    15.0         1.12         Albanian
#
#    outofpockethealthexpenditure  physiciansperthousand  population  \
# 0                          78.4                   0.28  38041754.0
# 1                          56.9                   1.20   2854191.0
#
#    populationlaborforceparticipation  taxrevenue  totaltaxrate  \
# 0                               48.9         9.3          71.4
# 1                               55.7        18.6          36.6
#
#    unemploymentrate  urbanpopulation  longitude   latitude
# 0             11.12        9797273.0  33.939110  67.709953
# 1             12.33        1747593.0  41.153332  20.168331

# %%
countries_by_continent = { 
                          "Africa": [ "Algeria", "Angola", "Benin", "Botswana", "Burkina Faso", "Burundi", "Cabo Verde", "Cameroon", "Central African Republic", "Chad", "Comoros", "Congo (Congo-Brazzaville)", "Democratic Republic of the Congo", "Djibouti", "Egypt", "Equatorial Guinea", "Eritrea", "Eswatini", "Ethiopia", "Gabon", "Gambia", "Ghana", "Guinea", "Guinea-Bissau", "Ivory Coast", "Kenya", "Lesotho", "Liberia", "Libya", "Madagascar", "Malawi", "Mali", "Mauritania", "Mauritius", "Morocco", "Mozambique", "Namibia", "Niger", "Nigeria", "Rwanda", "São Tomé and Príncipe", "Senegal", "Seychelles", "Sierra Leone", "Somalia", "South Africa", "South Sudan", "Sudan", "Tanzania", "Togo", "Tunisia", "Uganda", "Zambia", "Zimbabwe" ], 
                          "Asia": [ "Afghanistan", "Armenia", "Azerbaijan", "Bahrain", "Bangladesh", "Bhutan", "Brunei", "Cambodia", "China", "Cyprus", "Georgia", "India", "Indonesia", "Iran", "Iraq", "Israel", "Japan", "Jordan", "Kazakhstan", "Kuwait", "Kyrgyzstan", "Laos", "Lebanon", "Malaysia", "Maldives", "Mongolia", "Myanmar (Burma)", "Nepal", "North Korea", "Oman", "Pakistan", "Palestine State", "Philippines", "Qatar", "Saudi Arabia", "Singapore", "South Korea", "Sri Lanka", "Syria", "Tajikistan", "Thailand", "Timor-Leste", "Turkey", "Turkmenistan", "United Arab Emirates", "Uzbekistan", "Vietnam", "Yemen" ],
                          "Europe": [ "Albania", "Andorra", "Armenia", "Austria", "Azerbaijan", "Belarus", "Belgium", "Bosnia and Herzegovina","Bulgaria", "Croatia", "Cyprus", "Czech Republic (Czechia)", "Denmark", "Estonia", "Finland", "France", "Georgia", "Germany", "Greece", "Hungary", "Iceland", "Ireland", "Italy", "Kazakhstan", "Kosovo", "Latvia", "Liechtenstein", "Lithuania", "Luxembourg", "Malta", "Moldova", "Monaco", "Montenegro", "Netherlands", "North Macedonia", "Norway", "Poland", "Portugal", "Romania", "Russia", "San Marino", "Serbia", "Slovakia", "Slovenia", "Spain", "Sweden", "Switzerland", "Ukraine", "United Kingdom", "Vatican City (Holy See)" ],
                          "North America": [ "Antigua and Barbuda", "Bahamas", "Barbados", "Belize", "Canada", "Costa Rica", "Cuba", "Dominica", "Dominican Republic", "El Salvador", "Grenada", "Guatemala", "Haiti", "Honduras", "Jamaica", "Mexico", "Nicaragua", "Panama", "Saint Kitts and Nevis", "Saint Lucia", "Saint Vincent and the Grenadines", "Trinidad and Tobago", "United States of America" ], 
                          "South America": [ "Argentina", "Bolivia", "Brazil", "Chile", "Colombia", "Ecuador", "Guyana", "Paraguay", "Peru","Suriname", "Uruguay", "Venezuela" ], "Australia/Oceania": [ "Australia", "Fiji", "Kiribati", "Marshall Islands", "Micronesia", "Nauru", "New Zealand", "Palau", "Papua New Guinea", "Samoa", "Solomon Islands", "Tonga", "Tuvalu", "Vanuatu" ], 
                          "Antarctica": [] }

# %%
def asignar_continente (country):
    for continent, countries in countries_by_continent.items():
        if country in countries :
            return continent

# %%
df_inner['continent'] = df_inner['country'].apply(asignar_continente)

# %%
df_inner.head(2)
# Out:
#        country  density abbreviation  agriculturalland  landarea  \
# 0  Afghanistan       60           AF              58.1  652230.0
# 1      Albania      105           AL              43.1   28748.0
#
#    armedforcessize  birthrate  callingcode capitalmajorcity  co2emissions  \
# 0         323000.0      32.49         93.0            Kabul        8672.0
# 1           9000.0      11.78        355.0           Tirana        4536.0
#
#       cpi  cpichange currencycode  fertilityrate  forestedarea  gasolineprice  \
# 0  149.90        2.3          AFN           4.47           2.1           0.70
# 1  119.05        1.4          ALL           1.62          28.1           1.36
#
#             gdp  grossprimaryeducationenrollment  \
# 0  1.910135e+10                            104.0
# 1  1.527808e+10                            107.0
#
#    grosstertiaryeducationenrollment  infantmortality largestcity  \
# 0                               9.7             47.9       Kabul
# 1                              55.0              7.8      Tirana
#
#    lifeexpectancy  maternalmortalityratio  minimumwage officiallanguage  \
# 0            64.5                   638.0         0.43           Pashto
# 1            78.5                    15.0         1.12         Albanian
#
#    outofpockethealthexpenditure  physiciansperthousand  population  \
# 0                          78.4                   0.28  38041754.0
# 1                          56.9                   1.20   2854191.0
#
#    populationlaborforceparticipation  taxrevenue  totaltaxrate  \
# 0                               48.9         9.3          71.4
# 1                               55.7        18.6          36.6
#
#    unemploymentrate  urbanpopulation  longitude   latitude continent
# 0             11.12        9797273.0  33.939110  67.709953      Asia
# 1             12.33        1747593.0  41.153332  20.168331    Europe

# %% [markdown]
# Guarda el DataFrame después de los cambios creados después de los dos ejercicios anteriores para usarlo en el pairprogramming de mañana.

# %%
df_inner.to_csv('pair-gorupby-apply.csv')

# %% [markdown]
# ### Ejercicios groupby
#
# ¿Cuál es la densidad de población promedio por continente?

# %%
df_inner.groupby(["continent"])["population"].mean().reset_index()
# Out:
#            continent    population
# 0             Africa  2.602921e+07
# 1               Asia  9.952562e+07
# 2  Australia/Oceania  3.212496e+06
# 3             Europe  1.776785e+07
# 4      North America  1.193440e+07
# 5      South America  3.571443e+07

# %% [markdown]
# ¿Cuál es la esperanza de vida promedio por idioma oficial? Agrupa los países por idioma oficial y calcula la esperanza de vida promedio.

# %%
df_inner.groupby(["officiallanguage"])["lifeexpectancy"].mean().reset_index()
# Out:
#      officiallanguage  lifeexpectancy
# 0           Afrikaans       63.900000
# 1            Albanian       78.500000
# 2             Amharic       66.200000
# 3              Arabic       72.864706
# 4            Armenian       74.900000
# ..                ...             ...
# 71  Tuvaluan Language             NaN
# 72          Ukrainian       71.600000
# 73               Urdu       67.100000
# 74              Uzbek       71.600000
# 75         Vietnamese       75.300000
#
# [76 rows x 2 columns]

# %% [markdown]
# ¿Cuál es la tasa de mortalidad infantil promedio por moneda?

# %%
df_inner.groupby(["currencycode"])["infantmortality"].mean().reset_index()
# Out:
#     currencycode  infantmortality
# 0            AED         6.500000
# 1            AFN        47.900000
# 2            ALL         7.800000
# 3            AMD        11.000000
# 4            AOA        51.600000
# ..           ...              ...
# 128          XCD        15.183333
# 129          XOF        51.512500
# 130          YER        42.900000
# 131          ZAR        28.500000
# 132          ZMW        40.400000
#
# [133 rows x 2 columns]

# %% [markdown]
# ¿Cuál es el salario mínimo por continente?

# %%
df_inner.groupby(["continent"])["minimumwage"].min().reset_index()
# Out:
#            continent  minimumwage
# 0             Africa         0.01
# 1               Asia         0.05
# 2  Australia/Oceania         0.40
# 3             Europe         0.31
# 4      North America         0.05
# 5      South America         0.01

# %% [markdown]
# ¿Cuál es la tasa de impuestos total máxima por densidad de población por continente? Para solucionar este ejercicio puedes:
#
# Primero, necesitas calcular la tasa de impuestos total para cada continente. La tasa de impuestos total se encuentra en la columna "total_tax_rate".

# %%
# Convertir la columna totaltaxrate a tipo numérico
df_inner['totaltaxrate'] = pd.to_numeric(df_inner['totaltaxrate'], errors='coerce')

# Eliminar filas con valores NaN en totaltaxrate
df_inner = df_inner.dropna(subset=['totaltaxrate'])

#verificar el tipo de datos de la columna 
if not df_inner['totaltaxrate'].dtype == 'float64':
    raise ValueError("La columna 'totaltaxrate' no se ha convertido correctamente a tipo numérico")

# Realizar la operación de agrupación y obtener el mínimo utilizando la función personalizada
min_values = df_inner.groupby(["totaltaxrate"]).min().reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1870, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1869 try:
# -> 1870     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1871 except Exception as err:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# File /opt/homebrew/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2953, in min(a, axis, out, keepdims, initial, where)
#    2839 """
#    2840 Return the minimum of an array or minimum along an axis.
#    2841
#    (...)
#    2951 6
#    2952 """
# -> 2953 return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2954                       keepdims=keepdims, initial=initial, where=where)
#
# File /opt/homebrew/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
# ---> 86             return reduction(axis=axis, out=out, **passkwargs)
#      88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:6184, in Series.min(self, axis, skipna, numeric_only, **kwargs)
#    6176 @doc(make_doc("min", ndim=1))
#    6177 def min(
#    6178     self,
#    (...)
#    6182     **kwargs,
#    6183 ):
# -> 6184     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11937, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   11930 def min(
#   11931     self,
#   11932     axis: Axis | None = 0,
#    (...)
#   11935     **kwargs,
#   11936 ):
# > 11937     return self._stat_function(
#   11938         "min",
#   11939         nanops.nanmin,
#   11940         axis,
#   11941         skipna,
#   11942         numeric_only,
#   11943         **kwargs,
#   11944     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11926, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11924 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11926 return self._reduce(
#   11927     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11928 )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:6134, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6130     raise TypeError(
#    6131         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6132         "with non-numeric dtypes."
#    6133     )
# -> 6134 return op(delegate, skipna=skipna, **kwds)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:1092, in _nanminmax.<locals>.reduction(values, axis, skipna, mask)
#    1089 values, mask = _get_values(
#    1090     values, skipna, fill_value_typ=fill_value_typ, mask=mask
#    1091 )
# -> 1092 result = getattr(values, meth)(axis)
#    1093 result = _maybe_null_out(result, axis, mask, values.shape)
#
# File /opt/homebrew/lib/python3.11/site-packages/numpy/core/_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# TypeError: '<=' not supported between instances of 'str' and 'float'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 12
#       9     raise ValueError("La columna 'totaltaxrate' no se ha convertido correctamente a tipo numérico")
#      11 # Realizar la operación de agrupación y obtener el mínimo utilizando la función personalizada
# ---> 12 min_values = df_inner.groupby(["totaltaxrate"]).min().reset_index()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:3168, in GroupBy.min(self, numeric_only, min_count, engine, engine_kwargs)
#    3160     return self._numba_agg_general(
#    3161         grouped_min_max,
#    3162         executor.identity_dtype_mapping,
#    (...)
#    3165         is_max=False,
#    3166     )
#    3167 else:
# -> 3168     return self._agg_general(
#    3169         numeric_only=numeric_only,
#    3170         min_count=min_count,
#    3171         alias="min",
#    3172         npfunc=np.min,
#    3173     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1834, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc)
#    1825 @final
#    1826 def _agg_general(
#    1827     self,
#    (...)
#    1832     npfunc: Callable,
#    1833 ):
# -> 1834     result = self._cython_agg_general(
#    1835         how=alias,
#    1836         alt=npfunc,
#    1837         numeric_only=numeric_only,
#    1838         min_count=min_count,
#    1839     )
#    1840     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1925, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1922     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1923     return result
# -> 1925 new_mgr = data.grouped_reduce(array_func)
#    1926 res = self._wrap_agged_manager(new_mgr)
#    1927 out = self._wrap_aggregated_output(res)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1922, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1919 else:
#    1920     return result
# -> 1922 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1923 return result
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1872     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1873     # preserve the kind of exception that raised
# -> 1874     raise type(err)(msg) from err
#    1876 if ser.dtype == object:
#    1877     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->min,dtype->object]

# %% [markdown]
# Luego, calcula la densidad de población para cada continente. La densidad de población se encuentra en la columna "density".

# %%
df_inner.groupby(["continent"])["density"].mean().reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1870, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1869 try:
# -> 1870     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1871 except Exception as err:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2376, in GroupBy.mean.<locals>.<lambda>(x)
#    2373 else:
#    2374     result = self._cython_agg_general(
#    2375         "mean",
# -> 2376         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2377         numeric_only=numeric_only,
#    2378     )
#    2379     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:6226, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6218 @doc(make_doc("mean", ndim=1))
#    6219 def mean(
#    6220     self,
#    (...)
#    6224     **kwargs,
#    6225 ):
# -> 6226     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11969, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11962 def mean(
#   11963     self,
#   11964     axis: Axis | None = 0,
#    (...)
#   11967     **kwargs,
#   11968 ) -> Series | float:
# > 11969     return self._stat_function(
#   11970         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11971     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11926, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11924 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11926 return self._reduce(
#   11927     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11928 )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:6134, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6130     raise TypeError(
#    6131         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6132         "with non-numeric dtypes."
#    6133     )
# -> 6134 return op(delegate, skipna=skipna, **kwds)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string '182610847646383568134674043103503567115913753709471534482031756268340319226525872141112549182567152762292538' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df_inner.groupby(["continent"])["density"].mean().reset_index()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2374, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2367     return self._numba_agg_general(
#    2368         grouped_mean,
#    2369         executor.float_dtype_mapping,
#    2370         engine_kwargs,
#    2371         min_periods=0,
#    2372     )
#    2373 else:
# -> 2374     result = self._cython_agg_general(
#    2375         "mean",
#    2376         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2377         numeric_only=numeric_only,
#    2378     )
#    2379     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1925, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1922     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1923     return result
# -> 1925 new_mgr = data.grouped_reduce(array_func)
#    1926 res = self._wrap_agged_manager(new_mgr)
#    1927 out = self._wrap_aggregated_output(res)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/base.py:336, in SingleDataManager.grouped_reduce(self, func)
#     334 def grouped_reduce(self, func):
#     335     arr = self.array
# --> 336     res = func(arr)
#     337     index = default_index(len(res))
#     339     mgr = type(self).from_array(res, index)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1922, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1919 else:
#    1920     return result
# -> 1922 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1923 return result
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1872     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1873     # preserve the kind of exception that raised
# -> 1874     raise type(err)(msg) from err
#    1876 if ser.dtype == object:
#    1877     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# Ahora, divide la tasa de impuestos total entre la densidad de población para obtener la tasa de impuestos total por persona por kilómetro cuadrado.

# %% [markdown]
# Encuentra el país que tiene el valor más alto en esta nueva columna calculada.

# %% [markdown]
# ¿Cuál es el porcentaje de población urbana promedio por continente?

# %%
# Función para convertir la media a porcentaje
def media_a_porcentaje(media):
    return media * 100

# Calcular la media y aplicar la función de conversión a porcentaje
resultado = df_inner.groupby(["continent"])["urbanpopulation"].mean().reset_index()
resultado['urbanpopulation'] = resultado['urbanpopulation'].apply(media_a_porcentaje)

# %%
resultado
# Out:
#            continent  urbanpopulation
# 0             Africa     1.144114e+09
# 1               Asia     5.198903e+09
# 2  Australia/Oceania     2.563095e+08
# 3             Europe     1.432776e+09
# 4      North America     9.044854e+08
# 5      South America     2.999807e+09

# %% [markdown]
# ¿Cuál es la diferencia entre el PIB promedio y el gasto en salud de bolsillo promedio por idioma oficial? Para contestar esta pregunta dabes seguir los siguientes pasos:
#
# Agrupa el DataFrame por idioma oficial y calcula la media del Gasto de Bolsillo en salud (out_of_pocket_health_expenditure) y del GPD.

# %%
df_inner.groupby(["officiallanguage"])["outofpockethealthexpenditure"].mean().reset_index()
# Out:
#    officiallanguage  outofpockethealthexpenditure
# 0         Afrikaans                           7.7
# 1          Albanian                          56.9
# 2           Amharic                          37.8
# 3            Arabic                          38.0
# 4          Armenian                          81.6
# ..              ...                           ...
# 67          Turkish                          16.9
# 68        Ukrainian                          47.8
# 69             Urdu                          66.5
# 70            Uzbek                          42.7
# 71       Vietnamese                          43.5
#
# [72 rows x 2 columns]

# %% [markdown]
# Calcula la diferencia entre el PIB promedio y el gasto en salud de bolsillo promedio

# %%
# Calcular los promedios del PIB y el gasto en salud de bolsillo
promedio_pib = df_inner['gdp'].mean()
promedio_gasto_salud = df_inner['outofpockethealthexpenditure'].mean()

# Calcular la diferencia
diferencia = promedio_pib - promedio_gasto_salud

print("Promedio del PIB:", promedio_pib)
print("Promedio del gasto en salud de bolsillo:", promedio_gasto_salud)
print("Diferencia:", diferencia)
# Out:
# Promedio del PIB: 502273075633.4208
# Promedio del gasto en salud de bolsillo: 32.82747252747253
# Diferencia: 502273075600.5933

# %% [markdown]
# ¿Cuál es la tasa de maternidad promedio por tasa de impuestos total? Para resolver el ejercicio deberás:
#
# Primero, calcula la tasa de maternidad promedio para cada continente. Puedes usar la columna "maternal_mortality_ratio" que representa la tasa de mortalidad materna.

# %%
tasa_maternidad = df_inner.groupby(["continent"])["maternalmortalityratio"].mean().reset_index()
tasa_maternidad
# Out:
#            continent  maternalmortalityratio
# 0             Africa              414.041667
# 1               Asia               71.930233
# 2  Australia/Oceania               61.888889
# 3             Europe                7.944444
# 4      North America               81.277778
# 5      South America               88.083333

# %% [markdown]
# Calcula la tasa de impuestos total promedio para cada continente. Puedes usar la columna "total_tax_rate" que representa la tasa de impuestos total en cada continente.

# %%
total_tax = df_inner.groupby(["continent"])["totaltaxrate"].mean().reset_index()
total_tax
# Out:
#            continent  totaltaxrate
# 0             Africa     47.835417
# 1               Asia     32.397674
# 2  Australia/Oceania     37.609091
# 3             Europe     38.781579
# 4      North America     41.250000
# 5      South America     53.341667

# %% [markdown]
# Luego, divide la tasa de maternidad promedio por la tasa de impuestos total promedio para obtener la relación entre ambas tasas.

# %%
division = tasa_maternidad / total_tax
print(f'Relacion entre la tasa de maternidad y la tasa de impuestos: {division}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 division = tasa_maternidad / total_tax
#       2 print(f'Relacion entre la tasa de maternidad y la tasa de impuestos: {division}')
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/arraylike.py:210, in OpsMixin.__truediv__(self, other)
#     208 @unpack_zerodim_and_defer("__truediv__")
#     209 def __truediv__(self, other):
# --> 210     return self._arith_method(other, operator.truediv)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:7639, in DataFrame._arith_method(self, other, op)
#    7637 def _arith_method(self, other, op):
#    7638     if self._should_reindex_frame_op(other, op, 1, None, None):
# -> 7639         return self._arith_method_with_reindex(other, op)
#    7641     axis: Literal[1] = 1  # only relevant for Series other case
#    7642     other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:7771, in DataFrame._arith_method_with_reindex(self, right, op)
#    7769 new_left = left.iloc[:, lcols]
#    7770 new_right = right.iloc[:, rcols]
# -> 7771 result = op(new_left, new_right)
#    7773 # Do the join on the columns instead of using left._align_for_op
#    7774 #  to avoid constructing two potentially large/sparse DataFrames
#    7775 join_columns, _, _ = left.columns.join(
#    7776     right.columns, how="outer", level=None, return_indexers=True
#    7777 )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/arraylike.py:210, in OpsMixin.__truediv__(self, other)
#     208 @unpack_zerodim_and_defer("__truediv__")
#     209 def __truediv__(self, other):
# --> 210     return self._arith_method(other, operator.truediv)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:7647, in DataFrame._arith_method(self, other, op)
#    7644 self, other = self._align_for_op(other, axis, flex=True, level=None)
#    7646 with np.errstate(all="ignore"):
# -> 7647     new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7648 return self._construct_result(new_data)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:7690, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    7684     assert self.columns.equals(right.columns)
#    7685     # TODO: The previous assertion `assert right._indexed_same(self)`
#    7686     #  fails in cases with empty columns reached via
#    7687     #  _frame_arith_method_with_reindex
#    7688
#    7689     # TODO operate_blockwise expects a manager of the same type
# -> 7690     bm = self._mgr.operate_blockwise(
#    7691         # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    7692         # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7693         # "ArrayManager"
#    7694         # error: Argument 1 to "operate_blockwise" of "BlockManager" has
#    7695         # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7696         # "BlockManager"
#    7697         right._mgr,  # type: ignore[arg-type]
#    7698         array_op,
#    7699     )
#    7700     return self._constructor_from_mgr(bm, axes=bm.axes)
#    7702 elif isinstance(right, Series) and axis == 1:
#    7703     # axis=1 means we want to operate row-by-row
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/managers.py:1470, in BlockManager.operate_blockwise(self, other, array_op)
#    1466 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1467     """
#    1468     Apply array_op blockwise with another (aligned) BlockManager.
#    1469     """
# -> 1470     return operate_blockwise(self, other, array_op)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/ops.py:65, in operate_blockwise(left, right, array_op)
#      63 res_blks: list[Block] = []
#      64 for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 65     res_values = array_op(lvals, rvals)
#      66     if (
#      67         left_ea
#      68         and not right_ea
#      69         and hasattr(res_values, "reshape")
#      70         and not is_1d_only_ea_dtype(res_values.dtype)
#      71     ):
#      72         res_values = res_values.reshape(1, -1)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:285, in arithmetic_op(left, right, op)
#     281     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     283     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 285     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     287 return res_values
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:229, in _na_arithmetic_op(left, right, op, is_cmp)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)
#     227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
# --> 229         result = _masked_arith_op(left, right, op)
#     230     else:
#     231         raise
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:165, in _masked_arith_op(x, y, op)
#     163     # See GH#5284, GH#5035, GH#19448 for historical reference
#     164     if mask.any():
# --> 165         result[mask] = op(xrav[mask], yrav[mask])
#     167 else:
#     168     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %% [markdown]
# Encuentra el país con la tasa de maternidad más alta por punto porcentual de tasa de impuestos total.

# %% [markdown]
# ### Ejercicios bonus groupby:
#
# ¿Cuál es la tasa de natalidad máxima por área forestal por continente? Encuentra el país con la tasa de natalidad más alta por cada punto porcentual de área forestal.

# %% [markdown]
# ¿Cuál es la diferencia entre la tasa de impuestos total y la tasa de desempleo promedio por continente?
